# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnan-Raghavan/Logparser/blob/master/data_augmentation_with_python_chapter_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Augmentation with Python, Chapter 6

# %% [markdown]
# ## 🌻 Welcome to Chapter 6, "Text Augmentation with Machine Learning"
#
# In this chapter, you will learn:
#
# - Machine Learning models
#
# - Word augmenting
#
# - Sentence augmenting
#
# - Real-world NLP datasets
#
# - Reinforce learning through Python code

# %% [markdown]
# # Load Notebook

# %% [markdown]
# - This Notebook original link is:
#   - https://github.com/PacktPublishing/Data-Augmentation-with-Python/blob/main/data_augmentation_with_python_chapter_6.ipynb

# %% [markdown]
# # GitHub Clone

# %%
# !pip install gensim==4.2.0
import gensim
print(gensim.__version__)
# version4.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim==4.2.0 in /usr/local/lib/python3.9/dist-packages (4.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim==4.2.0) (6.3.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from gensim==4.2.0) (1.22.4)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.9/dist-packages (from gensim==4.2.0) (1.10.1)
# 4.2.0

# %%
# git version should be 2.17.1 or higher
# !git --version
# Out:
# git version 2.25.1

# %%
#url = 'https://github.com/PacktPublishing/Data-Augmentation-with-Python'
url = 'https://github.com/duchaba/Data-Augmentation-with-Python'
# !git clone {url}
# Out:
# fatal: destination path 'Data-Augmentation-with-Python' already exists and is not an empty directory.

# %% [markdown]
# ## Fetch file from URL (Optional)
#
# - Uncommend the below 2 code cells if you want to use URL and not Git Clone

# %%
# import requests
# #
# def fetch_file(url, dst):
#   downloaded_obj = requests.get(url)
#   with open(dst, "wb") as file:
#     file.write(downloaded_obj.content)
#   return

# %%
# url = ''
# dst = 'pluto_chapter_1.py'
# fetch_file(url,dst)

# %% [markdown]
# # Run Pluto
#
# - Instantiate up Pluto, aka. "Pluto, wake up!"

# %%
# %% CARRY-OVER code install

# !pip install opendatasets --upgrade
# !pip install pyspellchecker 
# !pip install missingno
# !pip install nltk
# !pip install wordcloud
# !pip install filter-profanity
# !pip install nlpaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.9/dist-packages (0.1.22)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.9/dist-packages (0.7.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingno in /usr/local/lib/python3.9/dist-packages (0.5.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from missingno) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from missingno) (1.10.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from missingno) (0.12.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (4.39.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (23.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->missingno) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->seaborn->missingno) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (4.39.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: filter-profanity in /usr/local/lib/python3.9/dist-packages (1.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.9/dist-packages (1.1.11)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (1.4.4)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (2.27.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (1.22.4)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (4.6.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (3.10.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (4.11.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->nlpaug) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (1.26.15)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)

# %%
#load and run the pluto chapter 1 Python code.
pluto_file = 'Data-Augmentation-with-Python/pluto/pluto_chapter_5.py'
# %run {pluto_file}
# Out:
# ---------------------------- : ----------------------------
#             Hello from class : <class '__main__.PacktDataAug'> Class: PacktDataAug
#                    Code name : Pluto
#                    Author is : Duc Haba
# ---------------------------- : ----------------------------
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Verify Pluto

# %%
pluto.say_sys_info()
# Out:
# ---------------------------- : ----------------------------
#                  System time : 2023/03/23 10:21
#                     Platform : linux
#      Pluto Version (Chapter) : 5.0
#              Python (3.7.10) : actual: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#             PyTorch (1.11.0) : actual: 1.13.1+cu116
#               Pandas (1.3.5) : actual: 1.4.4
#                  PIL (9.0.0) : actual: 8.4.0
#           Matplotlib (3.2.2) : actual: 3.7.1
#                    CPU count : 2
#                    CPU speed : 2.00 GHz
#                CPU max speed : 0.00 GHz
# ---------------------------- : ----------------------------

# %% [markdown]
# ## (Optional) Export to .py

# %%
pluto_chapter_6 = 'Data-Augmentation-with-Python/pluto/pluto_chapter_6.py'
# !cp {pluto_file} {pluto_chapter_6}

# %% [markdown]
# # ✋ Get Kaggle username and api key (Optional for this chapter)
#
# - Install the following libraries, and import it on the Notebook.
# - Follow by initialize Kaggle username, key and fetch methods.
# - STOP: Update your Kaggle access username or key first.

# %%
# -------------------- : --------------------
# READ ME
# Chapter 2 begin:
# Install the following libraries, and import it on the Notebook.
# Follow by initialize Kaggle username, key and fetch methods.
# STOP: Update your Kaggle access username or key first.
# -------------------- : --------------------

# !pip install opendatasets --upgrade
import opendatasets
print("\nrequired version 0.1.22 or higher: ", opendatasets.__version__)

# !pip install pyspellchecker 
import spellchecker
print("\nRequired version 0.7+", spellchecker.__version__)

# STOP: Update your Kaggle access username or key first.
pluto.remember_kaggle_access_keys("YOUR-USERNAME", "YOUR-KEY")
pluto._write_kaggle_credit()
import kaggle

@add_method(PacktDataAug)
def fetch_kaggle_comp_data(self,cname):
  #self._write_kaggle_credit()  # need to run only once.
  path = pathlib.Path(cname)
  kaggle.api.competition_download_cli(str(path))
  zipfile.ZipFile(f'{path}.zip').extractall(path)
  return

@add_method(PacktDataAug)
def fetch_kaggle_dataset(self,url,dest="kaggle"):
  #self._write_kaggle_credit()    # need to run only once.
  opendatasets.download(url,data_dir=dest)
  return
# -------------------- : --------------------
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.9/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
#
# required version 0.1.22 or higher:  0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.9/dist-packages (0.7.1)
#
# Required version 0.7+ 0.7.1

# %% [markdown]
# # Fetch data from chapter 5

# %%
f = 'Data-Augmentation-with-Python/pluto_data'
# !ls -la {f}
# Out:
# total 9372
# drwxr-xr-x 2 root root    4096 Mar 23 09:20 .
# drwxr-xr-x 6 root root    4096 Mar 23 09:20 ..
# -rw-r--r-- 1 root root  102877 Mar 23 09:20 control-d-major.mp3
# -rw-r--r-- 1 root root 3404721 Mar 23 09:20 netflix_data.csv
# -rw-r--r-- 1 root root 6072376 Mar 23 09:20 twitter_data.csv

# %%
f = 'Data-Augmentation-with-Python/pluto_data/netflix_data.csv'
pluto.df_netflix_data = pluto.fetch_df(f,sep='~')

# %%
f = 'Data-Augmentation-with-Python/pluto_data/twitter_data.csv'
pluto.df_twitter_data = pluto.fetch_df(f,sep='~')

# %%
pluto.print_batch_text(pluto.df_netflix_data, cols=['title','description'])
# Out:
# <style type="text/css">
# #T_9424f th {
#   font-size: 20px;
# }
# #T_9424f td {
#   font-size: 18px;
# }
# </style>
# <table id="T_9424f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9424f_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_9424f_level0_col1" class="col_heading level0 col1" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9424f_level0_row0" class="row_heading level0 row0" >1467</th>
#       <td id="T_9424f_row0_col0" class="data row0 col0" >Unknown</td>
#       <td id="T_9424f_row0_col1" class="data row0 col1" >Liam Neeson stars as a man who regains consciousness after a car accident, only to discover that another man is impersonating him.</td>
#     </tr>
#     <tr>
#       <th id="T_9424f_level0_row1" class="row_heading level0 row1" >4611</th>
#       <td id="T_9424f_row1_col0" class="data row1 col0" >Vettai</td>
#       <td id="T_9424f_row1_col1" class="data row1 col1" >This powerful Tamil action film follows the shared fate of two very different siblings policeman Thiru and his roguish brother, Guru.</td>
#     </tr>
#     <tr>
#       <th id="T_9424f_level0_row2" class="row_heading level0 row2" >8765</th>
#       <td id="T_9424f_row2_col0" class="data row2 col0" >XX</td>
#       <td id="T_9424f_row2_col1" class="data row2 col1" >This fourpart anthology of short horror films features stories that include some traditional themes but all are shown from a female point of view.</td>
#     </tr>
#     <tr>
#       <th id="T_9424f_level0_row3" class="row_heading level0 row3" >5331</th>
#       <td id="T_9424f_row3_col0" class="data row3 col0" >Naked</td>
#       <td id="T_9424f_row3_col1" class="data row3 col1" >Robs madly in love and about to be married. Unfortunately, hes also naked, stuck in an elevator and caught in a time loop.</td>
#     </tr>
#     <tr>
#       <th id="T_9424f_level0_row4" class="row_heading level0 row4" >4385</th>
#       <td id="T_9424f_row4_col0" class="data row4 col0" >The Ballad of Buster Scruggs</td>
#       <td id="T_9424f_row4_col1" class="data row4 col1" >Ranging from absurd to profound, these Western vignettes from the Coen brothers follow the adventures of outlaws and settlers on the American frontier.</td>
#     </tr>
#     <tr>
#       <th id="T_9424f_level0_row5" class="row_heading level0 row5" >4881</th>
#       <td id="T_9424f_row5_col0" class="data row5 col0" >Manhunt</td>
#       <td id="T_9424f_row5_col1" class="data row5 col1" >A Chinese pharmaceutical lawyer framed for a vile crime teams up with a sharpwitted Japanese detective to stop a dangerous corporate plot.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.draw_text_wordcloud(pluto.df_netflix_data.description, 
  xignore_words=wordcloud.STOPWORDS, 
  title='Word Cloud: Netflix Movie Review')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-60b8d82074af> in <module>
# ----> 1 pluto.draw_text_wordcloud(pluto.df_netflix_data.description,
#       2   xignore_words=wordcloud.STOPWORDS,
#       3   title='Word Cloud: Netflix Movie Review')
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in y(*args, **kwargs)
#      49     @functools.wraps(z)
#      50     def y(*args, **kwargs):
# ---> 51       return z(*args, **kwargs)
#      52     setattr(x, z.__name__, y)
#      53     return z
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in draw_text_wordcloud(self, df_1column, xignore_words, title)
#     302   orig = df_1column.str.cat()
#     303   clean = re.sub('[^A-Za-z0-9 ]+', '', orig)
# --> 304   self._draw_image_wordcloud(clean, xignore_words=xignore_words,title=title)
#     305   return
#     306
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in y(*args, **kwargs)
#      49     @functools.wraps(z)
#      50     def y(*args, **kwargs):
# ---> 51       return z(*args, **kwargs)
#      52     setattr(x, z.__name__, y)
#      53     return z
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in _draw_image_wordcloud(self, words_str, xignore_words, title)
#     294     labelbottom = False, bottom = False)
#     295   canvas.tight_layout()
# --> 296   self._drop_image(canvas)
#     297   canvas.show()
#     298   return
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in y(*args, **kwargs)
#      49     @functools.wraps(z)
#      50     def y(*args, **kwargs):
# ---> 51       return z(*args, **kwargs)
#      52     setattr(x, z.__name__, y)
#      53     return z
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in _drop_image(self, canvas, fname, format, dname)
#     158   else:
#     159     fn = fname
# --> 160   canvas.savefig(fn, cmap="Greys", bbox_inches="tight", pad_inches=0.25)
#     161   return
#     162 #
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# TypeError: print_jpg() got an unexpected keyword argument 'cmap'

# %%
pluto.draw_text_wordcloud(pluto.df_twitter_data.clean_tweet, 
  xignore_words=wordcloud.STOPWORDS, 
  title='Word Cloud: Twitter Tweets')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-2dd3459e2981> in <module>
# ----> 1 pluto.draw_text_wordcloud(pluto.df_twitter_data.clean_tweet,
#       2   xignore_words=wordcloud.STOPWORDS,
#       3   title='Word Cloud: Twitter Tweets')
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in y(*args, **kwargs)
#      49     @functools.wraps(z)
#      50     def y(*args, **kwargs):
# ---> 51       return z(*args, **kwargs)
#      52     setattr(x, z.__name__, y)
#      53     return z
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in draw_text_wordcloud(self, df_1column, xignore_words, title)
#     302   orig = df_1column.str.cat()
#     303   clean = re.sub('[^A-Za-z0-9 ]+', '', orig)
# --> 304   self._draw_image_wordcloud(clean, xignore_words=xignore_words,title=title)
#     305   return
#     306
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in y(*args, **kwargs)
#      49     @functools.wraps(z)
#      50     def y(*args, **kwargs):
# ---> 51       return z(*args, **kwargs)
#      52     setattr(x, z.__name__, y)
#      53     return z
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in _draw_image_wordcloud(self, words_str, xignore_words, title)
#     294     labelbottom = False, bottom = False)
#     295   canvas.tight_layout()
# --> 296   self._drop_image(canvas)
#     297   canvas.show()
#     298   return
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in y(*args, **kwargs)
#      49     @functools.wraps(z)
#      50     def y(*args, **kwargs):
# ---> 51       return z(*args, **kwargs)
#      52     setattr(x, z.__name__, y)
#      53     return z
#
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py in _drop_image(self, canvas, fname, format, dname)
#     158   else:
#     159     fn = fname
# --> 160   canvas.savefig(fn, cmap="Greys", bbox_inches="tight", pad_inches=0.25)
#     161   return
#     162 #
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
#    3345     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# TypeError: print_jpg() got an unexpected keyword argument 'cmap'

# %% [markdown]
# ## Extened control text

# %%
# %%writefile -a {pluto_chapter_6}

pluto.version = 7.0
#
pluto.orig_text = '''It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.'''
pluto.orig_dickens_page = '''There were a king with a large jaw and a queen with a plain face, 
on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France. 
In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes, 
that things in general were settled for ever.
It was the year of Our Lord one thousand seven hundred and seventy-five. 
Spiritual revelations were conceded to England at that favoured period, 
as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday, 
of whom a prophetic private in the Life Guards had heralded the sublime appearance 
by announcing that arrangements were made for the swallowing up of London and Westminster. 
Even the Cock-lane ghost had been laid only a round dozen of years, 
after rapping out its messages, 
as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs. 
Mere messages in the earthly order of events had lately come to the English Crown and People, 
from a congress of British subjects in America: which, strange to relate, 
have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.'''

pluto.orig_melville_page2 = '''Call me Ishmael. 
Some years ago—never mind how long precisely—having little or no money in my purse, 
and nothing particular to interest me on shore, 
I thought I would sail about a little and see the watery part of the world. 
It is a way I have of driving off the spleen and regulating the circulation.'''

pluto.orig_melville_page = '''Call me Ishmael. 
Some years ago—never mind how long precisely—having little or no money in my purse, 
and nothing particular to interest me on shore, 
I thought I would sail about a little and see the watery part of the world. 
It is a way I have of driving off the spleen and regulating the circulation. 
Whenever I find myself growing grim about the mouth; whenever it is a damp, 
drizzly November in my soul; 
whenever I find myself involuntarily pausing before coffin warehouses, 
and bringing up the rear of every funeral I meet; 
and especially whenever my hypos get such an upper hand of me, 
that it requires a strong moral principle to prevent me from deliberately stepping into the street, 
and methodically knocking people’s hats off—then, 
I account it high time to get to sea as soon as I can. 
This is my substitute for pistol and ball. 
With a philosophical flourish Cato throws himself upon his sword; 
I quietly take to the ship. There is nothing surprising in this. 
If they but knew it, almost all men in their degree, some time or other, 
cherish very nearly the same feelings towards the ocean with me.'''

#
pluto.orig_carroll_page = '''Alice was beginning to get very tired of sitting by her sister on the bank, 
and of having nothing to do. 
Once or twice she had peeped into the book her sister was reading, 
but it had no pictures or conversations in it. 
“and what is the use of a book,” thought Alice “without pictures or conversations?”
So she was considering in her own mind. as well as she could, 
for the hot day made her feel very sleepy and stupid. 
whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, 
when suddenly a White Rabbit with pink eyes ran close by her.
There was nothing so very remarkable in that; 
nor did Alice think it so very much out of the way to hear the Rabbit say to itself. 
“Oh dear! Oh dear! I shall be late!” 
when she thought it over afterwards, 
it occurred to her that she ought to have wondered at this, 
but at the time it all seemed quite natural; 
but when the Rabbit actually took a watch out of its waistcoat-pocket, 
and looked at it, and then hurried on, Alice started to her feet, 
for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket, 
or a watch to take out of it, 
and burning with curiosity, 
she ran across the field after it, 
and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.
'''
#
pluto.orig_carroll_page2 = '''Alice was beginning to get very tired of sitting by her sister on the bank, 
and of having nothing to do. 
Once or twice she had peeped into the book her sister was reading, 
but it had no pictures or conversations in it.
“and what is the use of a book,” thought Alice “without pictures or conversations?”
So she was considering in her own mind. as well as she could, 
for the hot day made her feel very sleepy and stupid. 
whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, 
when suddenly a White Rabbit with pink eyes ran close by her.'''
#
pluto.orig_self = '''Text augmentation with Machine Learning (ML) is an advanced technique. 
Ironically, Text augmentation aims to improve ML model accuracy, 
but we used a pre-trained ML model to create additional training NLP data. 
It’s a circular process. ML coding is not in this book’s scope, 
but understanding the difference between text augmentation using libraries and ML is beneficial.  
Augmentation libraries, whether for image, text, or audio, 
follow the traditional programming methodologies with structure data, loops, 
and conditional statements in the algorithm. 
For example, from Chapter 5, the pseudo-code for implementing the method _print_aug_reserved() could be as follows:'''

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def _clean_text(self,x):
  return (re.sub('[^A-Za-z0-9 .,!?#@]+', '', str(x)))

# %%
pluto.df_netflix_data['description'] = pluto.df_netflix_data['description'].apply(pluto._clean_text)

# %% [markdown]
# # Word2Vec

# %%
# !ls -la ../model/

# %%
# %%writefile -a {pluto_chapter_6}

from nlpaug.util.file.download import DownloadUtil

#DownloadUtil.download_word2vec(dest_dir='.') # word2vec
DownloadUtil.download_glove(model_name='glove.6B', dest_dir='.') # GloVe
DownloadUtil.download_fasttext(model_name='wiki-news-300d-1M', dest_dir='.') # fasttext model

# %%
# %%writefile -a {pluto_chapter_6}

try:
  DownloadUtil.download_word2vec(dest_dir='.') # word2vec
except Exception:
  print('\nIt happen frequently that this file can not be download due to too many access.')
  print('When it failed, you can not use Word2Vec transformation/augmentation.')
  print('You could download the file: GoogleNews-vectors-negative300.bin.gz')
  print('From URL: https://drive.google.com/uc?export=download&id=0B7XkCwpI5KDYNlNUTTlSS21pQmM \n')
# Out:
# Access denied with the following error:
#
# It happen frequently that this file can not be download due to too many access.
# When it failed, you can not use Word2Vec transformation/augmentation.
# You could download the file: GoogleNews-vectors-negative300.bin.gz
# From URL: https://drive.google.com/uc?export=download&id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?export=download&id=0B7XkCwpI5KDYNlNUTTlSS21pQmM

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
@add_method(PacktDataAug)
def print_aug_ai_word2vec(self, df, 
  col_dest="description",
  action='insert',
  model_type='word2vec',
  model_path='GoogleNews-vectors-negative300.bin',
  bsize=3, 
  aug_name='Augment',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.word.WordEmbsAug(model_type=model_type,action=action,model_path=model_path)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ai_word2vec(pluto.df_netflix_data,
  col_dest='description',
  action='insert',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_737dc th {
#   font-size: 20px;
# }
# #T_737dc td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_737dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_737dc_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_737dc_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_737dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_737dc_row0_col0" class="data row0 col0" >It was the pre best of Claro times. It Bullbars was the worst of times. K#####US It was the age of wisdom. Endometrial It bidding was the age guru of MAIDUGURI foolishness. It Dimitri was the epoch of belief. It was BOK the epoch of incredulity.</td>
#       <td id="T_737dc_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_737dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_737dc_row1_col0" class="data row1 col0" >mandu This World War IIera training film Gulnara dramatizes how RMB secret agents should act while undercover Briozzo and Rhiner how to controlled avoid capture by Bahia enemies.</td>
#       <td id="T_737dc_row1_col1" class="data row1 col1" >This World War IIera training film dramatizes how secret agents should act while undercover and how to avoid capture by enemies.</td>
#     </tr>
#     <tr>
#       <th id="T_737dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_737dc_row2_col0" class="data row2 col0" >Febreze Everyday guy Kabir is thrown for a Sport loop drought when Crosspool he meets surged Kuhu, cashew a culturally freewheeling party Abramowski girl. Nina Now, hes a changed man, dancing, running halfnaked through the streets and donning ladies Moratuwa shoes at her whim.</td>
#       <td id="T_737dc_row2_col1" class="data row2 col1" >Everyday guy Kabir is thrown for a loop when he meets Kuhu, a freewheeling party girl. Now, hes a changed man, dancing, running halfnaked through the streets and donning ladies shoes at her whim.</td>
#     </tr>
#     <tr>
#       <th id="T_737dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_737dc_row3_col0" class="data row3 col0" >In euHReka his first Pinoy special Wayne since his PHILIPPINE serious Moolchand car Shannon accident, Tracy Morgan cracks jokes about life in a Lloyd coma, his Everyday second marriage and his familys appalling dark side.</td>
#       <td id="T_737dc_row3_col1" class="data row3 col1" >In his first special since his serious car accident, Tracy Morgan cracks jokes about life in a coma, his second marriage and his familys dark side.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_word2vec(pluto.df_netflix_data,
  col_dest='description',
  action='insert',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_b8b25 th {
#   font-size: 20px;
# }
# #T_b8b25 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_b8b25" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8b25_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_b8b25_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8b25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8b25_row0_col0" class="data row0 col0" >It was the best of times. P. It was the worst Reps. of Pawling times. Marcus It S0 was the age of wisdom. It Manav was Stamp the File age of foolishness. It was Agon the EUROPEAN epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_b8b25_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_b8b25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b8b25_row1_col0" class="data row1 col0" >After failing William to Rene deliver for a Spanton demanding bride, a SooToday wedding boffo planner makes a bold business move and throws Balderrama the wrestler wedding of the Homerton year for Surgeon herself.</td>
#       <td id="T_b8b25_row1_col1" class="data row1 col1" >After failing to deliver for a demanding bride, a wedding planner makes a bold business move and throws the wedding of the year  for herself.</td>
#     </tr>
#     <tr>
#       <th id="T_b8b25_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b8b25_row2_col0" class="data row2 col0" >When the children Investor of binti two families become friends, acorns they begin to unravel a Omakase horrific Les crime in the past that DJ already linked their CJE fathers to Mychele each Steve other.</td>
#       <td id="T_b8b25_row2_col1" class="data row2 col1" >When the children of two families become friends, they begin to unravel a horrific crime in the past that already linked their fathers to each other.</td>
#     </tr>
#     <tr>
#       <th id="T_b8b25_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b8b25_row3_col0" class="data row3 col0" >This Pradeep documentary Alan series reconstructs historys most complex, SEAH highstakes hostage Rabelais negotiations as kidnapping victims actress recount their Famer terrifying ordeals.</td>
#       <td id="T_b8b25_row3_col1" class="data row3 col1" >This documentary series reconstructs historys most complex, highstakes hostage negotiations as kidnapping victims recount their terrifying ordeals.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_word2vec(pluto.df_twitter_data,col_dest='clean_tweet',action='insert',aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_88f8a th {
#   font-size: 20px;
# }
# #T_88f8a td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_88f8a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88f8a_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_88f8a_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88f8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88f8a_row0_col0" class="data row0 col0" >It was Admiral the Rielley best of times. It Baby was the worst Tom of times. It was the Alice age of wisdom. Dazzling It was the Islamâ age of Polyplex foolishness. It was the epoch of belief. It was Bodyweight the epoch of Passionfish incredulity.</td>
#       <td id="T_88f8a_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_88f8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88f8a_row1_col0" class="data row1 col0" >Rehana shooting, Brouker mass casualty Hyaluron situation at butane orlando gay nightclub breitba news. # heabreaking # Lt. orlandoshooting</td>
#       <td id="T_88f8a_row1_col1" class="data row1 col1" >shooting, mass casualty situation at orlando gay nightclub breitba news. #heabreaking #orlandoshooting</td>
#     </tr>
#     <tr>
#       <th id="T_88f8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_88f8a_row2_col0" class="data row2 col0" >some Hoople groups By have Dirk finished their presentations. # missiondiscoveryayrshire</td>
#       <td id="T_88f8a_row2_col1" class="data row2 col1" >some groups have finished their presentations. #missiondiscoveryayrshire</td>
#     </tr>
#     <tr>
#       <th id="T_88f8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_88f8a_row3_col0" class="data row3 col0" ># Dashiell create Ian something Croome beautiful for Warren another # day whatever you can # Jesse make have a Margorie go, and Keizo create! # pictures # a # words # Vook sewing # Freshfields poem</td>
#       <td id="T_88f8a_row3_col1" class="data row3 col1" >#create something beautiful for another #day whatever you can #make have a go, and create! #pictures #a #words #sewing #poem</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substitute

# %%
pluto.print_aug_ai_word2vec(pluto.df_netflix_data,
  col_dest='description',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_503fd th {
#   font-size: 20px;
# }
# #T_503fd td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_503fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_503fd_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_503fd_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_503fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_503fd_row0_col0" class="data row0 col0" >Regardless became the best of Edwing_Matos. Oddly_enough initially for worst of times. It was the age of truisms. It was the age of foolishness. It was certainly epoch of faith. It went the epoch of incredulity.</td>
#       <td id="T_503fd_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_503fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_503fd_row1_col0" class="data row1 col0" >Incurable romantic_interludes Lotte indulges her life dashed belatedly her plans for a pictureperfect wedding dismantle just as Gail_Quets selfabsorbed sister reaches engaged.</td>
#       <td id="T_503fd_row1_col1" class="data row1 col1" >Incurable romantic Lotte finds her life upended when her plans for a pictureperfect wedding unravel  just as her selfabsorbed sister gets engaged.</td>
#     </tr>
#     <tr>
#       <th id="T_503fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_503fd_row2_col0" class="data row2 col0" >Halfway tangy_sweet delicacies to dream roundtrip_fares, this museum_Verhoek iWeb_themes vibrant stories on cultural Westpac_ACCI across food, catwalk and agents_ASTA_SmartBrief in India.</td>
#       <td id="T_503fd_row2_col1" class="data row2 col1" >From delicious delicacies to dream destinations, this collection features vibrant stories on cultural trends across food, fashion and travel in India.</td>
#     </tr>
#     <tr>
#       <th id="T_503fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_503fd_row3_col0" class="data row3 col0" >A Arthur_Rimbaud and a photographer take a NEWARK_NJ_Jason_Arnott WHL_Roundup romance never find CRGP_Licensors_affiliates dreams and mishandled_bags can keep them from taking their relationship further.</td>
#       <td id="T_503fd_row3_col1" class="data row3 col1" >A poet and a photographer take a chance on romance but find their ambitions and baggage could keep them from taking their relationship further.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_word2vec(pluto.df_twitter_data,
  col_dest='clean_tweet',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_d060d th {
#   font-size: 20px;
# }
# #T_d060d td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_d060d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d060d_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_d060d_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d060d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d060d_row0_col0" class="data row0 col0" >It was before best of times. It subsequently the worst of times. It was my age of wisdom. Sadly remains the age of arrogance. It was the epoch of dogma. Sometimes blew_gasket the Kaliyuga of incredulity.</td>
#       <td id="T_d060d_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_d060d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d060d_row1_col0" class="data row1 col0" >agao Christmas_Eve of school! practice today, game Check_FresnoBee.com_throughout! gonna love nobody. whos? :) probly. ..</td>
#       <td id="T_d060d_row1_col1" class="data row1 col1" >last day of school! practice today, game tomorrow! gotta love it. whos ? haha abe...</td>
#     </tr>
#     <tr>
#       <th id="T_d060d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d060d_row2_col0" class="data row2 col0" ># nigger # pattismith paperback? ? any1, arnt marxist?</td>
#       <td id="T_d060d_row2_col1" class="data row2 col1" >#nigger #pattismith book?? wtf, thats reich?</td>
#     </tr>
#     <tr>
#       <th id="T_d060d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d060d_row3_col0" class="data row3 col0" >@ Genieo # 5/seniors # bihday # thalaivaaaaaa thalaivaa irfan bdayspl Oct.</td>
#       <td id="T_d060d_row3_col1" class="data row3 col1" >@user #adv #bihday #thalaivaaaaaa thalaivaa vijay bdayspl week</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_carroll_page], columns=['page'])
pluto.print_aug_ai_word2vec(df_page,
  col_dest='page',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_6364f th {
#   font-size: 20px;
# }
# #T_6364f td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_6364f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6364f_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_6364f_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6364f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6364f_row0_col0" class="data row0 col0" >Surely was the classiest of times. It wasn also worst of than. Although was the age of wisdom. It was the compulsory_schooling of foolishness. Thirdly was the Meiji_Era of belief. It was his epoch of incredulity.</td>
#       <td id="T_6364f_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_6364f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6364f_row1_col0" class="data row1 col0" >Edna was beginning to get very tired of sitting Fjeld_Evan_PNT_##:## her sister on the bank, and of having nothing to do. Once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it. “ and what is the use of a book, ” thought Alice “ without pictures or conversations? ” So she was considering in her own mind. as well as she could, for the hot day made her feel very sleepy and stupid. whether the pleasure of making a daisy - chain would be worth the trouble of getting ahead and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her. There was nothing so very dizzying in that; any did Alice think it so very much out of the way to hear the Goat say to itself. “ Oh dear! Oh dear! I subsection_b be late! ” when she thought it over afterwards, it happpened to her that she ought to have wondered at this, but at the time it all seemed quite natural; but when the Rabbit actually took a watch down of its waistcoat - pocket, and looked at it, and then hurried on, Alice started to her feet, for it flashed across her mind that she had never before seen a rabbit with either a waistcoat - pocket, or a watch to take out of it, and burning with curiosity, bubbly_outgoing ran across the field after it, and fortunately was just in time to see it pop down a large rabbit - hole under the hedge.</td>
#       <td id="T_6364f_row1_col1" class="data row1 col1" >Alice was beginning to get very tired of sitting by her sister on the bank,
# and of having nothing to do.
# Once or twice she had peeped into the book her sister was reading,
# but it had no pictures or conversations in it.
# “and what is the use of a book,” thought Alice “without pictures or conversations?”
# So she was considering in her own mind. as well as she could,
# for the hot day made her feel very sleepy and stupid.
# whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies,
# when suddenly a White Rabbit with pink eyes ran close by her.
# There was nothing so very remarkable in that;
# nor did Alice think it so very much out of the way to hear the Rabbit say to itself.
# “Oh dear! Oh dear! I shall be late!”
# when she thought it over afterwards,
# it occurred to her that she ought to have wondered at this,
# but at the time it all seemed quite natural;
# but when the Rabbit actually took a watch out of its waistcoat-pocket,
# and looked at it, and then hurried on, Alice started to her feet,
# for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket,
# or a watch to take out of it,
# and burning with curiosity,
# she ran across the field after it,
# and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.
# </td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_christie_page], columns=['page'])
pluto.print_aug_ai_word2vec(df_page,
  col_dest='page',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-171d0f6d49da> in <module>
# ----> 1 df_page = pandas.DataFrame([pluto.orig_christie_page], columns=['page'])
#       2 pluto.print_aug_ai_word2vec(df_page,
#       3   col_dest='page',
#       4   action='substitute',
#       5   aug_name='Word2Vec-GoogleNews Word Embedding Augment',
#
# AttributeError: 'PacktDataAug' object has no attribute 'orig_christie_page'

# %% [markdown]
# #BERT

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.27.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)

# %%
# %%writefile -a {pluto_chapter_6}

import transformers
print(transformers.__version__)
# Out:
# 4.27.2

# %%
# !pip install simpletransformers>=0.61.10
import simpletransformers
#print(simpletransformers.__version__)

# %%
# !pip install nltk>=3.4.5
# !pip install gensim>=4.1.2

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
@add_method(PacktDataAug)
def print_aug_ai_bert(self, df, 
  col_dest="description",
  action='insert',
  model_path='bert-base-uncased',
  bsize=3, 
  aug_name='Augment',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.word.ContextualWordEmbsAug(action=action,model_path=model_path)
  #self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name,is_orig_control=is_orig_control)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  action='insert',aug_name='BERT Embedding Insert Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_04e4f th {
#   font-size: 20px;
# }
# #T_04e4f td {
#   font-size: 18px;
# }
# </style>
# <table id="T_04e4f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04e4f_level0_col0" class="col_heading level0 col0" >BERT Embedding Insert Augment</th>
#       <th id="T_04e4f_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04e4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04e4f_row0_col0" class="data row0 col0" >it was from the best of other times. it was the worst of times. it truly was the ninth age of wisdom. it was the greatest age born of spiritual foolishness. it was for the first epoch of belief. it was from the epoch of incredulity.</td>
#       <td id="T_04e4f_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_04e4f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04e4f_row1_col0" class="data row1 col0" >a busy couple tries desperately to give others their love life a boost by once taking an impromptu shopping weekend trip only later to suddenly find their relationship get tested down in unexpected twist ways.</td>
#       <td id="T_04e4f_row1_col1" class="data row1 col1" >A busy couple tries to give their love life a boost by taking an impromptu weekend trip only to find their relationship tested in unexpected ways.</td>
#     </tr>
#     <tr>
#       <th id="T_04e4f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04e4f_row2_col0" class="data row2 col0" >when bella swan song moves in with her vampire father, she slowly starts school and also meets uncle edward, a slightly mysterious classmate who reveals himself out to be actually a mysterious 108yearold vampire.</td>
#       <td id="T_04e4f_row2_col1" class="data row2 col1" >When Bella Swan moves in with her father, she starts school and meets Edward, a mysterious classmate who reveals himself to be a 108yearold vampire.</td>
#     </tr>
#     <tr>
#       <th id="T_04e4f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04e4f_row3_col0" class="data row3 col0" >any eight extremely gleefully pretty grim ominous short tales set on halloween, mothers day, or st. patricks s day proper and other holidays would comprise within this chilling horror anthology.</td>
#       <td id="T_04e4f_row3_col1" class="data row3 col1" >Eight gleefully grim short tales set on Halloween, Mothers Day, St. Patricks Day and other holidays comprise this chilling horror anthology.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  action='insert',aug_name='BERT Embedding Insert Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_d49e0 th {
#   font-size: 20px;
# }
# #T_d49e0 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_d49e0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d49e0_level0_col0" class="col_heading level0 col0" >BERT Embedding Insert Augment</th>
#       <th id="T_d49e0_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d49e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d49e0_row0_col0" class="data row0 col0" >it was the best of times. it probably was the worst days of old times. it was the age giving of wisdom. it was the age of irrational foolishness. finally it was the epoch making of faulty belief. it really was the greatest epoch of incredulity.</td>
#       <td id="T_d49e0_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_d49e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d49e0_row1_col0" class="data row1 col0" >oh oh dear. why more are people dying for young? # the ripcharity</td>
#       <td id="T_d49e0_row1_col1" class="data row1 col1" >oh dear. why are people dying young? #ripcharity</td>
#     </tr>
#     <tr>
#       <th id="T_d49e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d49e0_row2_col0" class="data row2 col0" >eyebrow football game said so weak</td>
#       <td id="T_d49e0_row2_col1" class="data row2 col1" >eyebrow game so weak</td>
#     </tr>
#     <tr>
#       <th id="T_d49e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d49e0_row3_col0" class="data row3 col0" >now be and # more stressfree! # free intro added to # spiritual vedic # meditation on sunday july 1st 10, 2008 4530pm at home 1848 e w 18th 20th st, in # art chicago # chicagomeditation</td>
#       <td id="T_d49e0_row3_col1" class="data row3 col1" >be and #stressfree! #free intro to #vedic #meditation on sunday july 10, 4530pm at 1848 w 18th st, in #chicago #chicagomeditation</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substitute

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  action='substitute',aug_name='BERT Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_d4799 th {
#   font-size: 20px;
# }
# #T_d4799 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_d4799" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4799_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_d4799_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4799_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4799_row0_col0" class="data row0 col0" >it is the best of times. it was the end of times. it was the age of wisdom. it was his age in reality. earth seemed the epoch without belief. it had th epoch of incredulity.</td>
#       <td id="T_d4799_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_d4799_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4799_row1_col0" class="data row1 col0" >after faking an illness to skip camp, bad guy ferris smith enjoys having funfilled day touring chicago with either girlfriend or my other best friend.</td>
#       <td id="T_d4799_row1_col1" class="data row1 col1" >After faking an illness to skip school, popular teen Ferris Bueller enjoys a funfilled day in Chicago with his girlfriend and his uptight best friend.</td>
#     </tr>
#     <tr>
#       <th id="T_d4799_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4799_row2_col0" class="data row2 col0" >friends, associates and critics reveal the short unbelievable story of donald hamilton, the successful businessman suddenly changes marriage rules to marry u. states. president.</td>
#       <td id="T_d4799_row2_col1" class="data row2 col1" >Friends, associates and critics reveal the truly American story of Donald Trump, the brash businessman who defied the odds to become U.S. president.</td>
#     </tr>
#     <tr>
#       <th id="T_d4799_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4799_row3_col0" class="data row3 col0" >after this family takes steps to catch on, a new yorker grieving sick moms death takes two angeles where new friends usually bring him out of his misery.</td>
#       <td id="T_d4799_row3_col1" class="data row3 col1" >As his father takes steps to move on, a New Yorker grieving his moms death visits Los Angeles where new possibilities may bring him out of his funk.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  action='substitute',aug_name='BERT Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_75cce th {
#   font-size: 20px;
# }
# #T_75cce td {
#   font-size: 18px;
# }
# </style>
# <table id="T_75cce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75cce_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_75cce_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75cce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75cce_row0_col0" class="data row0 col0" >it was at best during days. it was the worst between cycles. it was the age to wisdom. it was the age of foolishness. it was both epoch around greed. it was the epoch around incredulity.</td>
#       <td id="T_75cce_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_75cce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75cce_row1_col0" class="data row1 col0" >wherever you were, whenever you can you have your or still miss you and..... mode</td>
#       <td id="T_75cce_row1_col1" class="data row1 col1" >wherever you are, whenever you maybe you know that i still love you forever..... mode</td>
#     </tr>
#     <tr>
#       <th id="T_75cce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75cce_row2_col0" class="data row2 col0" >2017 looking forward with another few shows being announced with backwards titles today on # console # dvd # rdr # rockstargames</td>
#       <td id="T_75cce_row2_col1" class="data row2 col1" >im looking forward to a few titles being announced as backwards compatible today on #xboxone #trials #rdr #rockstargames</td>
#     </tr>
#     <tr>
#       <th id="T_75cce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75cce_row3_col0" class="data row3 col0" >took my first step in learning much about my former life when pulling an # ancestrydna test.</td>
#       <td id="T_75cce_row3_col1" class="data row3 col1" >took the first step in learning more about my family heritage by ordering an #ancestrydna test.</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_dickens_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  action='substitute',
  aug_name='BERT Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_96f2a th {
#   font-size: 20px;
# }
# #T_96f2a td {
#   font-size: 18px;
# }
# </style>
# <table id="T_96f2a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96f2a_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_96f2a_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96f2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96f2a_row0_col0" class="data row0 col0" >who held the best to times. this was definitely worst from times. it stopped the age of wisdom. it was the age of foolishness. it became the epoch of belief. he was the epoch of evolution.</td>
#       <td id="T_96f2a_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_96f2a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96f2a_row1_col0" class="data row1 col0" >there were a king with a large jaw and a queen with a plain face, on another throne of spain ; there were a king with a large jaw and a queen with a fair face, on the throne of france. between both countries it was clearer than crystal to the people of the state preserves of loaves and fishes, that things in general were settled for ever. it was the year of our lord one thousand seven hundred four seventy - five. spiritual revelations were conceded to england at that favoured period, as at this. mrs. southcott had recently attained her five - and - twentieth blessed birthday, of whom a prophetic private in the life service had heralded the sublime appearance by announcing that arrangements were made for immediately swallowing up of london and westminster. even the cock - gate ghost had been laid only a round dozen of years, after rapping out its messages, as the spirits of the very year last past ( supernaturally deficient in originality ) rapped out theirs. mere messages in the earthly order of events had lately entered to the english crown and people, from a congress of british subjects in america : which, strange to relate, have proved more important to the human race than any communications yet received through any of the chickens of the cock - lane brood.</td>
#       <td id="T_96f2a_row1_col1" class="data row1 col1" >There were a king with a large jaw and a queen with a plain face,
# on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
# that things in general were settled for ever.
# It was the year of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that arrangements were made for the swallowing up of London and Westminster.
# Even the Cock-lane ghost had been laid only a round dozen of years,
# after rapping out its messages,
# as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People,
# from a congress of British subjects in America: which, strange to relate,
# have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_christie_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  action='substitute',
  aug_name='BERT Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-c9a0c1c33825> in <module>
#       1 df_page = pandas.DataFrame([pluto.orig_carroll_page2], columns=['page'])
# ----> 2 pluto.print_aug_ai_bert(df_page,
#       3   col_dest='page',
#       4   action='substitute',
#       5   aug_name='BERT Embedding Substitute Augment',
#
# AttributeError: 'PacktDataAug' object has no attribute 'print_aug_ai_bert'

# %% [markdown]
# # RoBERTa

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  model_path='roberta-base',
  action='insert',aug_name='Roberta Embedding Insert Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_4ab39 th {
#   font-size: 20px;
# }
# #T_4ab39 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_4ab39" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ab39_level0_col0" class="col_heading level0 col0" >Roberta Embedding Insert Augment</th>
#       <th id="T_4ab39_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ab39_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ab39_row0_col0" class="data row0 col0" >It was the best of times. *** It never was the worst period of times. … It was never the age of epic wisdom. It probably was the age of supreme foolishness. … It was the greatest epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_4ab39_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_4ab39_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ab39_row1_col0" class="data row1 col0" >While quickly acclimating themselves to campus life, college freshman student Sara begins to realize that somehow her new best roommate, one Rebecca, is gradually becoming borderline obsessed sexually with her.</td>
#       <td id="T_4ab39_row1_col1" class="data row1 col1" >While acclimating to campus life, college freshman Sara begins to realize that her new roommate, Rebecca, is becoming obsessed with her.</td>
#     </tr>
#     <tr>
#       <th id="T_4ab39_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4ab39_row2_col0" class="data row2 col0" >An aspiring music director quickly begins to receive voyeuristic found footage recordings of video his new girlfriend snapping from her apparent male stalker as more tragedy strikes those around him.</td>
#       <td id="T_4ab39_row2_col1" class="data row2 col1" >An aspiring music director begins to receive voyeuristic footage of his girlfriend from her apparent stalker as tragedy strikes those around him.</td>
#     </tr>
#     <tr>
#       <th id="T_4ab39_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4ab39_row3_col0" class="data row3 col0" >Scienceloving host host Emily Calandrelli makes STEAM fun – with activities, informative demonstrations and and hilarious athome experiments -- thatll definitely make make you think  and blow opening your creative mind!</td>
#       <td id="T_4ab39_row3_col1" class="data row3 col1" >Scienceloving host Emily Calandrelli makes STEAM fun with activities, demonstrations and athome experiments thatll make you think  and blow your mind!</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  model_path='roberta-base',
  action='insert',aug_name='Roberta Embedding Insert Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_e1e5d th {
#   font-size: 20px;
# }
# #T_e1e5d td {
#   font-size: 18px;
# }
# </style>
# <table id="T_e1e5d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1e5d_level0_col0" class="col_heading level0 col0" >Roberta Embedding Insert Augment</th>
#       <th id="T_e1e5d_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1e5d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1e5d_row0_col0" class="data row0 col0" >It was the best of times. It was at the worst end of times. It was the last age of wisdom. It truly was the age of reckless foolishness. It was the epoch of blind belief. It really was all the fourth epoch of great incredulity.</td>
#       <td id="T_e1e5d_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_e1e5d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1e5d_row1_col0" class="data row1 col0" >the sun springs and the devils would den the kinda only thing really on my mind since rn.</td>
#       <td id="T_e1e5d_row1_col1" class="data row1 col1" >the springs and the devils den the only thing on my mind rn.</td>
#     </tr>
#     <tr>
#       <th id="T_e1e5d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1e5d_row2_col0" class="data row2 col0" >were u brilliant at doing the bits on that many dont get in in touch or we may now be seeing able something to help #change #business</td>
#       <td id="T_e1e5d_row2_col1" class="data row2 col1" >were brilliant at doing the bits that many dont get in touch we may be able to help #change #business</td>
#     </tr>
#     <tr>
#       <th id="T_e1e5d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1e5d_row3_col0" class="data row3 col0" >go root germany! = #gogermany ~ #em # #em2016 ## #family | #love # #germany #selfie #selca | #lovemyfamily | #smile # #ger</td>
#       <td id="T_e1e5d_row3_col1" class="data row3 col1" >go germany! #gogermany #em #em2016 #family #love #germany #selfie #selca #lovemyfamily #smile #ger</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substitute

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  model_path='roberta-base',
  action='substitute',aug_name='Roberta Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_0956a th {
#   font-size: 20px;
# }
# #T_0956a td {
#   font-size: 18px;
# }
# </style>
# <table id="T_0956a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0956a_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_0956a_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0956a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0956a_row0_col0" class="data row0 col0" >It was the best of times. It was the worst of times. It was the time of wisdom. It was the age of skepticism. It be that epoch without belief. It been another dawn if absurdity.</td>
#       <td id="T_0956a_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_0956a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0956a_row1_col0" class="data row1 col0" >A looming eclipse by Jupiter forces Earth and humans search for a host star. My cosmic fate now rests in the hand of a few unexpected heroes.</td>
#       <td id="T_0956a_row1_col1" class="data row1 col1" >A looming collision with Jupiter threatens Earth as humans search for a new star. The planets fate now lies in the hands of a few unexpected heroes.</td>
#     </tr>
#     <tr>
#       <th id="T_0956a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0956a_row2_col0" class="data row2 col0" >Lonewolf mayor Bill Walker is back, to aim at another U.S. Constitution and his police pursuit of some FBI agents whom are on his run.</td>
#       <td id="T_0956a_row2_col1" class="data row2 col1" >Lonewolf vigilante Bill Williamson is back, taking aim at the U.S. government and eluding the pursuit of two FBI agents who are on his trail.</td>
#     </tr>
#     <tr>
#       <th id="T_0956a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0956a_row3_col0" class="data row3 col0" >A gang of teens become caught off onto a monster hunt before vengeful clones representing centuries past rise up in the Liberdade district of Port Paulo.</td>
#       <td id="T_0956a_row3_col1" class="data row3 col1" >A group of teens get caught up in a supernatural clash as vengeful spirits from centuries past rise up in the Liberdade district of So Paulo.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  model_path='roberta-base',
  action='substitute',aug_name='Roberta Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_551cb th {
#   font-size: 20px;
# }
# #T_551cb td {
#   font-size: 18px;
# }
# </style>
# <table id="T_551cb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_551cb_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_551cb_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_551cb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_551cb_row0_col0" class="data row0 col0" >It was really end times times. It was is worst of tests. It ruined the stage of wisdom. It was a age for foolishness. It was the epoch de belief. It was the epoch of incredulity.</td>
#       <td id="T_551cb_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_551cb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_551cb_row1_col0" class="data row1 col0" >i guess am i supposed like get married know about your life #datemyfamily</td>
#       <td id="T_551cb_row1_col1" class="data row1 col1" >i think am not supposed to get married fact about my life #datemyfamily</td>
#     </tr>
#     <tr>
#       <th id="T_551cb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_551cb_row2_col0" class="data row2 col0" >cleaned down my bunk.</td>
#       <td id="T_551cb_row2_col1" class="data row2 col1" >cleaned up my notifications.</td>
#     </tr>
#     <tr>
#       <th id="T_551cb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_551cb_row3_col0" class="data row3 col0" >when you only have to live paycheck to scrap, life will thus much shorter 🙂</td>
#       <td id="T_551cb_row3_col1" class="data row3 col1" >when you dont have to live paycheck to paycheck, life seems so much simpler #madeit</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_dickens_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  model_path='roberta-base',
  action='substitute',
  aug_name='Roberta Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_296fc th {
#   font-size: 20px;
# }
# #T_296fc td {
#   font-size: 18px;
# }
# </style>
# <table id="T_296fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_296fc_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_296fc_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_296fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_296fc_row0_col0" class="data row0 col0" >It went the best of times. It was in light of times. It seemed an age of wisdom. It was an age of hope. It was the epoch of belief. It also the epoch after uncertainty.</td>
#       <td id="T_296fc_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_296fc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_296fc_row1_col0" class="data row1 col0" >There were a king with a large jaw and a queen with a plain face,
# on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to lesser lords of the State preserves and loaves and fishes,
# that relations in general were settled for ever.
# It was the will of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that arrangements were made for the swallowing up of London and Westminster.
# Even the Cock-lane ghost had been laid only a round table of years,
# after rapping out its messages,
# as the spirits of this very year last past was deficient in originality) rapped out theirs.
# Mere messages respecting the earthly order of events had lately come for the English Crown and People,
# from a congress of British subjects in America: translations, strange to relate,
# have proved more timely to the human race than any communications yet received through any of the chickens of the Cock-lane brood.</td>
#       <td id="T_296fc_row1_col1" class="data row1 col1" >There were a king with a large jaw and a queen with a plain face,
# on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
# that things in general were settled for ever.
# It was the year of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that arrangements were made for the swallowing up of London and Westminster.
# Even the Cock-lane ghost had been laid only a round dozen of years,
# after rapping out its messages,
# as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People,
# from a congress of British subjects in America: which, strange to relate,
# have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_christie_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  model_path='roberta-base',
  action='substitute',
  aug_name='Roberta Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-4e8917307ad8> in <module>
# ----> 1 df_page = pandas.DataFrame([pluto.orig_christie_page], columns=['page'])
#       2 pluto.print_aug_ai_bert(df_page,
#       3   col_dest='page',
#       4   model_path='roberta-base',
#       5   action='substitute',
#
# AttributeError: 'PacktDataAug' object has no attribute 'orig_christie_page'

# %% [markdown]
# # Back Translation

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.9/dist-packages (0.0.53)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses) (8.1.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacremoses) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sacremoses) (4.65.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.1.1)

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def print_aug_ai_back_translation(self, df, col_dest="description",
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  bsize=3, aug_name='Augment',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.word.BackTranslationAug(from_model_name=from_model_name,
    to_model_name=to_model_name)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ai_back_translation(pluto.df_netflix_data,col_dest='description',
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  aug_name='FaceBook Back Translation: English <-> German Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_2c556 th {
#   font-size: 20px;
# }
# #T_2c556 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_2c556" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c556_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> German Augment</th>
#       <th id="T_2c556_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c556_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c556_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of folly. It was the age of faith. It was the age of unbelief.</td>
#       <td id="T_2c556_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_2c556_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c556_row1_col0" class="data row1 col0" >The fragile and mysterious world of two sisters and their uncle disintegrates when their charming cousin arrives overlooking family happiness.</td>
#       <td id="T_2c556_row1_col1" class="data row1 col1" >The fragile and secretive world of two sisters and their uncle crumbles when their charming cousin arrives with eyes toward the family fortune.</td>
#     </tr>
#     <tr>
#       <th id="T_2c556_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2c556_row2_col0" class="data row2 col0" >Donald Rumsfeld reviews his long political career, from his time in Congress to his time as defense secretary under Gerald Ford and George W. Bush.</td>
#       <td id="T_2c556_row2_col1" class="data row2 col1" >Donald Rumsfeld reviews his long political career, from his time in Congress to serving as secretary of defense under Gerald Ford and George W. Bush.</td>
#     </tr>
#     <tr>
#       <th id="T_2c556_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2c556_row3_col0" class="data row3 col0" >A disillusioned cook tries to help her parents renovate their failing hotel, but is seething with feelings for an investor who has his sights set on the property.</td>
#       <td id="T_2c556_row3_col1" class="data row3 col1" >A disenchanted chef tries to help her parents restore their failing hotel but cooks up feelings for an investor with his sights set on the property.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# https://huggingface.co/models

# %%
pluto.print_aug_ai_back_translation(pluto.df_twitter_data,col_dest='clean_tweet',
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  aug_name='FaceBook Back Translation: English <-> German Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_6481b th {
#   font-size: 20px;
# }
# #T_6481b td {
#   font-size: 18px;
# }
# </style>
# <table id="T_6481b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6481b_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> German Augment</th>
#       <th id="T_6481b_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6481b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6481b_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of folly. It was the age of faith. It was the age of unbelief.</td>
#       <td id="T_6481b_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_6481b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6481b_row1_col0" class="data row1 col0" >wake up every day and be thankful. every day is a gift, make the best of it and don't take it for granted. # feeling</td>
#       <td id="T_6481b_row1_col1" class="data row1 col1" >wake up every day and be thankful. every day is a gift, make the most of it and dont take it for granted. #feeling</td>
#     </tr>
#     <tr>
#       <th id="T_6481b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6481b_row2_col0" class="data row2 col0" >Happy feet. # throwback # holiday # solotrip # solooverseastrip # australia # ausbound</td>
#       <td id="T_6481b_row2_col1" class="data row2 col1" >happy feet. #throwback #holiday #solotrip #solooverseastrip #australia #ausbound</td>
#     </tr>
#     <tr>
#       <th id="T_6481b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6481b_row3_col0" class="data row3 col0" >spoke too soon! my wallpaper is here! I know what I did wrong tonight! good job, I used to buy some glue</td>
#       <td id="T_6481b_row3_col1" class="data row3 col1" >spoke too soon! my wallpaper is here! know what ill be doing tonight then! good job i bought some adhesive earlier</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_back_translation(pluto.df_netflix_data,col_dest='description',
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  aug_name='FaceBook Back Translation: English <-> German Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_26e89 th {
#   font-size: 20px;
# }
# #T_26e89 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_26e89" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26e89_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> German Augment</th>
#       <th id="T_26e89_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26e89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26e89_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of folly. It was the age of faith. It was the age of unbelief.</td>
#       <td id="T_26e89_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_26e89_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26e89_row1_col0" class="data row1 col0" >A diamond heist goes horribly wrong, and the group of friends who wanted to make a fortune must instead fight for their survival.</td>
#       <td id="T_26e89_row1_col1" class="data row1 col1" >A diamond heist goes horribly wrong, and the group of friends who sought to make a fortune must instead fight for their very survival.</td>
#     </tr>
#     <tr>
#       <th id="T_26e89_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26e89_row2_col0" class="data row2 col0" >An Egyptian doctor becomes a police informant and uses his rare gift to track down ancient artifacts in the smuggling business.</td>
#       <td id="T_26e89_row2_col1" class="data row2 col1" >An Egyptian doctor becomes a police informant and uses his rare gift of tracking ancient artifacts in the smuggling business.</td>
#     </tr>
#     <tr>
#       <th id="T_26e89_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26e89_row3_col0" class="data row3 col0" >Discover the true stories behind these iconic Christmas blockbusters with inside interviews and behind-the-scenes insights.</td>
#       <td id="T_26e89_row3_col1" class="data row3 col1" >Unwrap the real stories behind these iconic Christmas blockbusters, thanks to insider interviews and behindthescenes peeks.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Russian

# %%
pluto.print_aug_ai_back_translation(pluto.df_netflix_data,col_dest='description',
  from_model_name='facebook/wmt19-en-ru', 
  to_model_name='facebook/wmt19-ru-en',
  aug_name='FaceBook Back Translation: English <-> Russian Augment')

# %%
pluto.print_aug_ai_back_translation(pluto.df_twitter_data,col_dest='clean_tweet',
  from_model_name='facebook/wmt19-en-ru', 
  to_model_name='facebook/wmt19-ru-en',
  aug_name='FaceBook Back Translation: English <-> Russian Augment')

# %% [markdown]
# # T5-Base

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def _fetch_larger_font(self):
  heading_properties = [('font-size', '20px')]
  cell_properties = [('font-size', '18px'), ('text-align', 'left')]
  dfstyle = [dict(selector="th", props=heading_properties),
    dict(selector="td", props=cell_properties)]
  return dfstyle

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def _print_aug_ai(self, orig, aug_func, 
  bsize=2, aug_name='Augmented',is_larger_font=True):
  aug = aug_func.augment(orig)
  data = [[aug[0]]]
  df_aug = pandas.DataFrame(data, columns=[aug_name])
  #
  if (bsize > 1):
    for i in range(bsize-1):
      aug = aug_func.augment(orig)
      data = [[aug[0]]]
      t = pandas.DataFrame(data, columns=[aug_name])
      df_aug = df_aug.append(t, ignore_index=True)
  #
  with pandas.option_context("display.max_colwidth", None):
    if (is_larger_font):
      # df_aug.style.set_properties(**{'text-align': 'left'})
      # display(df_aug.style.set_properties(**{'text-align': 'left'}))
      display(df_aug.style.set_table_styles(self._fetch_larger_font()))
    else:
      display(df_aug)
  return df_aug
#
@add_method(PacktDataAug)
def print_aug_ai_t5(self, orig, 
  bsize=2, 
  aug_name='T5_summary',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.sentence.AbstSummAug(model_path='t5-base')
  df = self._print_aug_ai(orig, aug_func,bsize=bsize, aug_name=aug_name)
  return df

# %%
pluto.df_t5_carroll = pluto.print_aug_ai_t5(pluto.orig_carroll_page, bsize=1)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# <style type="text/css">
# #T_c0b10 th {
#   font-size: 20px;
# }
# #T_c0b10 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_c0b10" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0b10_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0b10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0b10_row0_col0" class="data row0 col0" >a white rabbit with pink eyes ran close by. the rabbit took a watch out of its waistcoat-pocket, and then hurried on. she ran across the field after it, and was just in time to see it pop down a rabbit-hole.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_carroll = pluto.print_aug_ai_t5(pluto.orig_carroll_page2, bsize=1)
# Out:
# <style type="text/css">
# #T_b070d th {
#   font-size: 20px;
# }
# #T_b070d td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_b070d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b070d_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b070d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b070d_row0_col0" class="data row0 col0" >white rabbit with pink eyes runs close by a daisy-chain maker. the daisies are made from a variety of flowers.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_melville = pluto.print_aug_ai_t5(pluto.orig_melville_page, bsize=1)
# Out:
# <style type="text/css">
# #T_880ee th {
#   font-size: 20px;
# }
# #T_880ee td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_880ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_880ee_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_880ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_880ee_row0_col0" class="data row0 col0" >Ishmael is a sailor who has a way of driving off the spleen and regulating the circulation. he says it is his substitute for pistol and ball to get to sea as soon as he can. almost all men in their degree, some time or other, cherish very nearly the same feelings.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_dickens = pluto.print_aug_ai_t5(pluto.orig_dickens_page, bsize=1)
# Out:
# <style type="text/css">
# #T_a0a59 th {
#   font-size: 20px;
# }
# #T_a0a59 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_a0a59" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0a59_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0a59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0a59_row0_col0" class="data row0 col0" >david rothkopf: spiritual revelations were conceded to England at favoured time. he says even the Cock-lane ghost had been laid only a round dozen of years. the spirits of this very year last past rapped out theirs, he writes.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_self = pluto.print_aug_ai_t5(pluto.orig_self, bsize=1)
# Out:
# <style type="text/css">
# #T_7a15e th {
#   font-size: 20px;
# }
# #T_7a15e td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_7a15e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a15e_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a15e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a15e_row0_col0" class="data row0 col0" >text augmentation with machine learning (ML) is an advanced technique. we used a pre-trained ML model to create additional training NLP data.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Sentense flow

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug.augmenter.word
import nlpaug.augmenter.sentence
import nlpaug.flow
pluto.ai_aug_glove = nlpaug.augmenter.word.WordEmbsAug(
    model_type='glove', model_path='glove.6B.300d.txt',
    action="substitute")
#
pluto.ai_aug_glove.aug_p=0.5
#
pluto.ai_aug_bert = nlpaug.augmenter.word.ContextualWordEmbsAug(
    model_path='bert-base-uncased', 
    action='substitute', top_k=20)

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
@add_method(PacktDataAug)
def print_aug_ai_sequential(self, df, 
  aug_name="T5_summary",
  bsize=4):
  aug_func = nlpaug.flow.Sequential([self.ai_aug_bert, self.ai_aug_glove])
  orig = df[aug_name][0]
  self._print_aug_ai(orig, aug_func,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.df_t5_carroll.T5_summary[0]
# Out:
# 'white rabbit with pink eyes runs close by a daisy-chain maker. the daisies are made from a variety of flowers.'

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_carroll)
# Out:
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_b858e th {
#   font-size: 20px;
# }
# #T_b858e td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_b858e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b858e_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b858e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b858e_row0_col0" class="data row0 col0" >shirts rabbit with coloured eyes games close by not snake - shape maker. are roses initially booming addition a few history plants.</td>
#     </tr>
#     <tr>
#       <th id="T_b858e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b858e_row1_col0" class="data row1 col0" >medalist wears way pink eyes runs them over made buchanan - selling coordinator. the visiting are it like a collection of twigs.</td>
#     </tr>
#     <tr>
#       <th id="T_b858e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b858e_row2_col0" class="data row2 col0" >white rat uses small breasts when move making a hot - supermarkets maker. the celery are him into he particularly same flowers.</td>
#     </tr>
#     <tr>
#       <th id="T_b858e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b858e_row3_col0" class="data row3 col0" >white hare for chocolate surface runs close out to perky - store maker. skirt daisies were also went before variety of production.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_dickens)
# Out:
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_c3ac8 th {
#   font-size: 20px;
# }
# #T_c3ac8 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_c3ac8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3ac8_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3ac8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3ac8_row0_col0" class="data row0 col0" >david rothkopf: new revelations were conceded must ireland at favoured periods. one 'll think grandmother cock - gravel ghost had been grounds only than round dozen life years. the spirit of this very place itself after rapped out. .. , and writes.</td>
#     </tr>
#     <tr>
#       <th id="T_c3ac8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3ac8_row1_col0" class="data row1 col0" >scott writes: pilgrimage revelations were complained want england closed favoured time. he says. .. the green - lane ghost apparently been laid only once short forty of years. many belief of your troubled previous which past carried out theirs, he writes.</td>
#     </tr>
#     <tr>
#       <th id="T_c3ac8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3ac8_row2_col0" class="data row2 col0" >david rothkopf: spiritual revelations. .. conceded only one sunday establishment time. he asked even the cock - nosed bride had been awake only before round dozen third years. the spirits living our very year them past had before theirs, carter books.</td>
#     </tr>
#     <tr>
#       <th id="T_c3ac8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3ac8_row3_col0" class="data row3 col0" >clarke says: spiritual revelations were shown attempting her on favoured time. he has however the cock - eyed lonely had been laid only on upset dozen upon it. before spirits there this very year beginning past complimented of theirs, was writes.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_melville)
# Out:
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_6299a th {
#   font-size: 20px;
# }
# #T_6299a td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_6299a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6299a_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6299a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6299a_row0_col0" class="data row0 col0" >one is a man he has a way of driving straight of spleen for regulating the circulation. he says did is. 78th for pistol and ball to need to naval be soon which he lands. almost those men in certain journalism, some time or other, carry more nearly the same feelings.</td>
#     </tr>
#     <tr>
#       <th id="T_6299a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6299a_row1_col0" class="data row1 col0" >ishmael and his sailor who has a way of driving at excess spleen and reducing the shimbun. he says indeed be his substitute addition pistol and goal he n't must sea also soon as he can. almost all men in this degree, some never or other, strived very nearly any fatal disdain.</td>
#     </tr>
#     <tr>
#       <th id="T_6299a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6299a_row2_col0" class="data row2 col0" >ishmael present a sailor who has way way he keep off the storm with regulating the circulation. . says it provides his substitute for ship and ball to get to sea as many rather he dies. not though men in their volunteers, some, each other, cherish very nearly the all feelings.</td>
#     </tr>
#     <tr>
#       <th id="T_6299a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6299a_row3_col0" class="data row3 col0" >ishmael is three sailor who explores a way of driving n't since spleen and regulating the readership. richard says it is his mission for 50-meter and ball to sleigh off sea as clean as he can. almost all 50 at already degree, some time or other, have very nearly the following feelings.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_self)
# Out:
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-32-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_54ec5 th {
#   font-size: 20px;
# }
# #T_54ec5 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_54ec5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54ec5_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54ec5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54ec5_row0_col0" class="data row0 col0" >memory stenting for machine techniques (ms) which an early equipment. take used our caliber - trained ml approach to retrieve rebuilt processed pjl samples.</td>
#     </tr>
#     <tr>
#       <th id="T_54ec5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54ec5_row1_col0" class="data row1 col0" >text creation followed source code (hat) is good editing technique. would used a custom - volunteered ml squad to create coming practicing years consumer.</td>
#     </tr>
#     <tr>
#       <th id="T_54ec5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54ec5_row2_col0" class="data row2 col0" >script language desktop machine learning (pd) keep set leading imaging. we merge into pre - existing computer system with provide reduced complex nlp programs.</td>
#     </tr>
#     <tr>
#       <th id="T_54ec5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_54ec5_row3_col0" class="data row3 col0" >correspondence augmentation using mortars ml (ml) becomes part important tactics. we provide only full - trained hardware model to process offering skills data data.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# end of chapter 6

# %% [markdown]
# # Push up all changes (Optional)

# %%
# import os
# f = 'Data-Augmentation-with-Python'
# os.chdir(f)
# !git add -A
# !git config --global user.email "duc.haba@gmail.com"
# !git config --global user.name "duchaba"
# !git commit -m "end of session"
# # do the git push in the xterm console
# #!git push

# %% [markdown]
# # Summary
#
# Every chaper will begin with same base class "PacktDataAug".
#
# ✋ FAIR WARNING:
#
# - The coding uses long and complete function path name.
#
# - Pluto wrote the code for easy to understand and not for compactness, fast execution, nor cleaverness.
#
# - Use Xterm to debug cloud server

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
